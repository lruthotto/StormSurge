# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#load in data and turn it into the uTrue
u=pd.read_csv("/Users/loganknudsen/Documents/GitHub/StormSurge/Experiment_Data/data_single_cases_analysis/smbt11950smbtf2300smb00.3smb10.15smbf0.0sillmin415sillmax425sillslope0.01hnd2.18lnd4.44bx-0.001.csv")
u
# Out:
#             t         H         L        1H        1L        2H        2L  \
# 0        0.00  2.180000  4.440000  0.000000  0.000000  0.000000  0.000000
# 1        0.25  2.180000  4.439999  2.301766  4.591735  2.289158  4.583491
# 2        0.50  2.180000  4.439998  2.301853  4.591502  2.289256  4.583237
# 3        0.75  2.180001  4.439996  2.301939  4.591271  2.289354  4.582984
# 4        1.00  2.180001  4.439995  2.302025  4.591040  2.289451  4.582731
# ...       ...       ...       ...       ...       ...       ...       ...
# 9196  2299.00  2.012985  3.683019  2.057402  3.659445  2.050677  3.669490
# 9197  2299.25  2.012892  3.682542  2.057215  3.659156  2.050512  3.669156
# 9198  2299.50  2.012800  3.682065  2.057027  3.658868  2.050347  3.668823
# 9199  2299.75  2.012707  3.681589  2.056839  3.658580  2.050182  3.668489
# 9200  2300.00  2.012613  3.681114  2.056651  3.658291  2.050017  3.668156
#
#             3H        3L        4H  ...        7H        7L        8H  \
# ...

# %%
square_diff_H = (u["aH"]-u["H"])**2
square_diff_H.mean()
# Out:
# 0.009824325380324263

# %%
square_diff_L = (u["aL"]-u["L"])**2
square_diff_L.mean()
# Out:
# 0.009409180498186313

# %%
#load in data and turn it into the uTrue
u2=pd.read_csv("/Users/loganknudsen/Documents/GitHub/StormSurge/Experiment_Data/data_single_cases_analysis/smbt11950smbtf2300smb00.35smb10.15smbf0.0sillmin415sillmax425sillslope0.0018hnd2.3lnd4.6bx-0.001_fixed_obs.csv")
u2
# Out:
#             t         H         L        1H        1L        2H        2L  \
# 0        0.00  2.180000  4.440000  0.000000  0.000000  0.000000  0.000000
# 1        0.25  2.180000  4.439999  2.294681  4.597650  2.297036  4.605272
# 2        0.50  2.180000  4.439998  2.294785  4.597382  2.297144  4.604993
# 3        0.75  2.180001  4.439996  2.294888  4.597114  2.297251  4.604715
# 4        1.00  2.180001  4.439995  2.294991  4.596847  2.297358  4.604439
# ...       ...       ...       ...       ...       ...       ...       ...
# 9196  2299.00  2.012985  3.683019  1.997366  3.731390  1.993794  3.655706
# 9197  2299.25  2.012892  3.682542  1.997339  3.730766  1.993702  3.655235
# 9198  2299.50  2.012800  3.682065  1.997312  3.730143  1.993610  3.654764
# 9199  2299.75  2.012707  3.681589  1.997284  3.729522  1.993517  3.654294
# 9200  2300.00  2.012613  3.681114  1.997256  3.728901  1.993424  3.653825
#
#             3H        3L        4H  ...        7H        7L        8H  \
# ...

# %%
square_diff_H2 = (u2["aH"]-u2["H"])**2
square_diff_H2.mean()
# Out:
# 0.003528871500947937

# %%
square_diff_L2 = (u2["aL"]-u2["L"])**2
square_diff_L2.mean()
# Out:
# 0.0032813478490220267
